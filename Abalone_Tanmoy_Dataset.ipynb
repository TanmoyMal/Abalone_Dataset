# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

data = pd.read_csv("/content/abalone.csv")

# pd.set_option('display.max_rows', None)

data
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
data.shape
# Out:
# (4177, 9)

# %%
data.head(10)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
# 5   I   0.425     0.300   0.095        0.3515          0.1410          0.0775
# 6   F   0.530     0.415   0.150        0.7775          0.2370          0.1415
# 7   F   0.545     0.425   0.125        0.7680          0.2940          0.1495
# 8   M   0.475     0.370   0.125        0.5095          0.2165          0.1125
# 9   F   0.550     0.440   0.150        0.8945          0.3145          0.1510
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# ...

# %%
data.tail(10)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4167   M   0.500     0.380   0.125        0.5770          0.2690
# 4168   F   0.515     0.400   0.125        0.6150          0.2865
# 4169   M   0.520     0.385   0.165        0.7910          0.3750
# 4170   M   0.550     0.430   0.130        0.8395          0.3155
# 4171   M   0.560     0.430   0.155        0.8675          0.4000
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4167          0.1265        0.1535      9
# 4168          0.1230        0.1765      8
# 4169          0.1800        0.1815     10
# 4170          0.1955        0.2405     10
# ...

# %%
df = pd.read_csv("/content/abalone.csv", usecols=['Whole weight', 'Viscera weight'])
df

#read the particulat row from the data set
# Out:
#       Whole weight  Viscera weight
# 0           0.5140          0.1010
# 1           0.2255          0.0485
# 2           0.6770          0.1415
# 3           0.5160          0.1140
# 4           0.2050          0.0395
# ...            ...             ...
# 4172        0.8870          0.2390
# 4173        0.9660          0.2145
# 4174        1.1760          0.2875
# 4175        1.0945          0.2610
# 4176        1.9485          0.3765
#
# [4177 rows x 2 columns]

# %%
df["Whole weight"].mean()


print("Mean of Whole weight:", df["Whole weight"].mean())

#the mean value of a particular row
# Out:
# Mean of Whole weight: 0.8287421594445774

# %%
df["Whole weight"].median()


print("Mean of Whole weight:", df["Whole weight"].median())

#the median value of a particular row
# Out:
# Mean of Whole weight: 0.7995

# %%
df["Viscera weight"].mode()[0]


print("Mode of Viscera weight:", df["Viscera weight"].mode()[0])


#the mode value of a particular row
# Out:
# Mode of Viscera weight: 0.1715

# %%
data.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
data.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
data.isnull()
# Out:
#         Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     False   False     False   False         False           False
# 1     False   False     False   False         False           False
# 2     False   False     False   False         False           False
# 3     False   False     False   False         False           False
# 4     False   False     False   False         False           False
# ...     ...     ...       ...     ...           ...             ...
# 4172  False   False     False   False         False           False
# 4173  False   False     False   False         False           False
# 4174  False   False     False   False         False           False
# 4175  False   False     False   False         False           False
# 4176  False   False     False   False         False           False
#
#       Viscera weight  Shell weight  Rings
# 0              False         False  False
# 1              False         False  False
# ...

# %%
dt=data.iloc[1:3]
print(dt)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 1   M    0.35     0.265   0.090        0.2255          0.0995          0.0485
# 2   F    0.53     0.420   0.135        0.6770          0.2565          0.1415
#
#    Shell weight  Rings
# 1          0.07      7
# 2          0.21      9

# %%
data.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
data2=data['Height'].value_counts()
print(data2)
# Out:
# Height
# 0.150    267
# 0.140    220
# 0.155    217
# 0.175    211
# 0.160    205
# 0.125    202
# 0.165    193
# 0.135    189
# 0.145    182
# 0.130    169
# 0.120    169
# 0.170    160
# 0.100    145
# 0.110    135
# 0.115    133
# 0.180    131
# 0.090    124
# 0.105    114
# 0.185    103
# 0.190    103
# 0.095     91
# 0.195     78
# 0.080     76
# 0.085     74
# 0.200     68
# 0.075     61
# 0.070     47
# 0.205     45
# 0.065     39
# 0.215     31
# 0.060     26
# 0.055     25
# 0.210     23
# 0.050     18
# 0.220     17
# 0.040     13
# 0.225     13
# 0.045     11
# 0.230     10
# 0.030      6
# 0.035      6
# 0.235      6
# 0.025      5
# 0.240      4
# 0.250      3
# 0.020      2
# 0.015      2
# 0.000      2
# 0.010      1
# 0.515      1
# 1.130      1
# Name: count, dtype: int64

# %%
sns.pairplot(data[['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight','Viscera weight', 'Shell weight', 'Rings']])
plt.suptitle('Pairplot of Features', y=1.02)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data[['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight','Viscera weight', 'Shell weight', 'Rings']])
plt.title('Boxplot of Features')
plt.show()

# %%
avg_measurements = data[['Height', 'Whole weight', 'Shucked weight','Viscera weight', 'Shell weight', 'Rings']].mean()
sns.barplot(x=avg_measurements.index, y=avg_measurements.values)
plt.title('Barplot of Average Measurements')
plt.ylabel('Average Measurement')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data['Length'], y=data['Height'], hue=data['Sex'])
plt.title('Scatterplot of Length vs Height')
plt.xlabel('Length')
plt.ylabel('Height')
plt.legend(title='Species')
plt.show()

# %%
corr=data[['Height', 'Whole weight', 'Shucked weight','Viscera weight', 'Shell weight', 'Rings']].corr()
sns.heatmap(corr)
# Out:
# <Axes: >
